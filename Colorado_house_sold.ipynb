# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
SC_df = pd.read_csv('Sale_Counts_State.csv')

# %%
SC_df.head()
# Out:
#    RegionID  RegionName  SizeRank  2008-03  2008-04  2008-05  2008-06  \
# 0         9  California         1  23365.0  28452.0  31222.0  32895.0
# 1        54       Texas         2  24876.0  27095.0  27758.0  28985.0
# 2        43    New York         3      NaN      NaN      NaN      NaN
# 3        14     Florida         4  17454.0  19512.0  19679.0  20452.0
# 4        21    Illinois         5  11619.0  12907.0  13627.0  14964.0
#
#    2008-07  2008-08  2008-09  ...  2018-11  2018-12  2019-01  2019-02  \
# 0  36549.0  35170.0  36246.0  ...    32585    30234    26244    28089
# 1  29439.0  26309.0  22307.0  ...    29595    29384    22848    23952
# 2      NaN      NaN      NaN  ...    15336    14336    13444    10657
# 3  20812.0  17529.0  17784.0  ...    37305    37385    33192    32401
# 4  16181.0  14749.0  13884.0  ...    16322    15262    11160    11203
#
#    2019-03  2019-04  2019-05  2019-06  2019-07  2019-08
# 0    34837    38725  43956.0  39623.0  42665.0  39568.0
# ...

# %%
CO_df = SC_df.loc[SC_df["RegionName"] == "Colorado", : ]
CO_df
# Out:
#     RegionID RegionName  SizeRank  2008-03  2008-04  2008-05  2008-06  \
# 21        10   Colorado        22   6978.0   7629.0   8125.0   8719.0
#
#     2008-07  2008-08  2008-09  ...  2018-11  2018-12  2019-01  2019-02  \
# 21   9163.0   7987.0   7587.0  ...     8291     7687     6632     6809
#
#     2019-03  2019-04  2019-05  2019-06  2019-07  2019-08
# 21     8815     9976  11494.0  11610.0  12375.0  10444.0
#
# [1 rows x 141 columns]

# %%
Date_df = pd.DataFrame(CO_df)
Date_df
# Out:
#     RegionID RegionName  SizeRank  2008-03  2008-04  2008-05  2008-06  \
# 21        10   Colorado        22   6978.0   7629.0   8125.0   8719.0
#
#     2008-07  2008-08  2008-09  ...  2018-11  2018-12  2019-01  2019-02  \
# 21   9163.0   7987.0   7587.0  ...     8291     7687     6632     6809
#
#     2019-03  2019-04  2019-05  2019-06  2019-07  2019-08
# 21     8815     9976  11494.0  11610.0  12375.0  10444.0
#
# [1 rows x 141 columns]

# %%
Date_df.T
# Out:
#                   21
# RegionID          10
# RegionName  Colorado
# SizeRank          22
# 2008-03         6978
# 2008-04         7629
# 2008-05         8125
# 2008-06         8719
# 2008-07         9163
# 2008-08         7987
# 2008-09         7587
# 2008-10         8183
# 2008-11         5193
# 2008-12         5479
# 2009-01         4256
# 2009-02         4436
# 2009-03         5630
# 2009-04         5672
# 2009-05         6046
# 2009-06         7667
# 2009-07         7855
# 2009-08         7056
# 2009-09         6779
# 2009-10         6968
# 2009-11         6668
# 2009-12         5973
# 2010-01         4262
# 2010-02         4295
# 2010-03         6775
# 2010-04         7089
# 2010-05         7666
# ...              ...
# 2017-03         9677
# 2017-04         9617
# 2017-05        11950
# 2017-06        12722
# 2017-07        11598
# 2017-08        12219
# 2017-09        10454
# 2017-10        10924
# 2017-11         9424
# 2017-12         8760
# 2018-01         7121
# ...

# %%
Date_df.head()
# Out:
#     RegionID RegionName  SizeRank  2008-03  2008-04  2008-05  2008-06  \
# 21        10   Colorado        22   6978.0   7629.0   8125.0   8719.0
#
#     2008-07  2008-08  2008-09  ...  2018-11  2018-12  2019-01  2019-02  \
# 21   9163.0   7987.0   7587.0  ...     8291     7687     6632     6809
#
#     2019-03  2019-04  2019-05  2019-06  2019-07  2019-08
# 21     8815     9976  11494.0  11610.0  12375.0  10444.0
#
# [1 rows x 141 columns]

# %%
date_data_df = Date_df.T[3:]
reset = date_data_df.reset_index()
split = reset['index'].str.split('-',n=2,expand=True)
merge_df = pd.merge(split,reset,left_index=True,right_index=True)
merge_df
# Out:
#         0   1    index     21
# 0    2008  03  2008-03   6978
# 1    2008  04  2008-04   7629
# 2    2008  05  2008-05   8125
# 3    2008  06  2008-06   8719
# 4    2008  07  2008-07   9163
# 5    2008  08  2008-08   7987
# 6    2008  09  2008-09   7587
# 7    2008  10  2008-10   8183
# 8    2008  11  2008-11   5193
# 9    2008  12  2008-12   5479
# 10   2009  01  2009-01   4256
# 11   2009  02  2009-02   4436
# 12   2009  03  2009-03   5630
# 13   2009  04  2009-04   5672
# 14   2009  05  2009-05   6046
# 15   2009  06  2009-06   7667
# 16   2009  07  2009-07   7855
# 17   2009  08  2009-08   7056
# 18   2009  09  2009-09   6779
# 19   2009  10  2009-10   6968
# 20   2009  11  2009-11   6668
# 21   2009  12  2009-12   5973
# 22   2010  01  2010-01   4262
# 23   2010  02  2010-02   4295
# 24   2010  03  2010-03   6775
# 25   2010  04  2010-04   7089
# 26   2010  05  2010-05   7666
# 27   2010  06  2010-06   8316
# 28   2010  07  2010-07   6100
# 29   2010  08  2010-08   5755
# ...

# %%
merge_df.groupby([0]).sum()
# Out:
#                              1  \
# 0
# 2008      03040506070809101112
# 2009  010203040506070809101112
# 2010  010203040506070809101112
# 2011  010203040506070809101112
# 2012  010203040506070809101112
# 2013  010203040506070809101112
# 2014  010203040506070809101112
# 2015  010203040506070809101112
# 2016  010203040506070809101112
# 2017  010203040506070809101112
# 2018  010203040506070809101112
# 2019          0102030405060708
#
#                                                   index        21
# 0
# 2008  2008-032008-042008-052008-062008-072008-082008...   75043.0
# 2009  2009-012009-022009-032009-042009-052009-062009...   75006.0
# 2010  2010-012010-022010-032010-042010-052010-062010...   72002.0
# 2011  2011-012011-022011-032011-042011-052011-062011...   73092.0
# 2012  2012-012012-022012-032012-042012-052012-062012...   87356.0
# 2013  2013-012013-022013-032013-042013-052013-062013...  102795.0
# 2014  2014-012014-022014-032014-042014-052014-062014...  106420.0
# ...

# %%
house_08 = CO_df[['2008-03','2008-04','2008-05', '2008-06', '2008-07', '2008-08', '2008-09', '2008-10', '2008-11', '2008-12']]

house_08 = house_08.sum(axis=1)
house_08

df1 = house_08.to_frame(name='House Count')
df1

df1['year'] = 2008
df1
# Out:
#     House Count  year
# 21      75043.0  2008

# %%
house_09 = CO_df[['2009-01','2009-02','2009-03','2009-04','2009-05', '2009-06', '2009-07', '2009-08', '2009-09', '2009-10', '2009-11', '2009-12']]
CO_df

house_09 = house_09.sum(axis=1)
house_09

df2 = house_09.to_frame(name="House Count")
df2

df2['year'] = 2009
df2
# Out:
#     House Count  year
# 21      75006.0  2009

# %%
house_10 = CO_df[['2010-01','2010-02','2010-03','2010-04','2010-05', '2010-06', '2010-07', '2010-08', '2010-09', '2010-10', '2010-11', '2010-12']]
house_10

house_10 = house_10.sum(axis=1)
house_10

df3 = house_10.to_frame(name="House Count")
df3

df3['year'] = 2010
df3
# Out:
#     House Count  year
# 21      72002.0  2010

# %%
house_11 = CO_df[['2011-01','2011-02','2011-03','2011-04','2011-05', '2011-06', '2011-07', '2011-08', '2011-09', '2011-10', '2011-11', '2011-12']]
house_11

house_11 = house_11.sum(axis=1)
house_11

df4 = house_11.to_frame(name="House Count")
df4

df4['year'] = 2011
df4
# Out:
#     House Count  year
# 21      73092.0  2011

# %%
house_12 = CO_df[['2012-01','2012-02','2012-03','2012-04','2012-05', '2012-06', '2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12']]
house_12

house_12 = house_12.sum(axis=1)
house_12

df5 = house_12.to_frame(name="House Count")
df5

df5['year'] = 2012

# %%
house_13 = CO_df[['2013-01','2013-02','2013-03','2013-04','2013-05', '2013-06', '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12']]
house_13

house_13 = house_13.sum(axis=1)
house_13

df6 = house_13.to_frame(name="House Count")
df6

df6['year'] = 2013
df6
# Out:
#     House Count  year
# 21     102795.0  2013

# %%
house_14 = CO_df[['2014-01','2014-02','2014-03','2014-04','2014-05', '2014-06', '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12']]
house_14

house_14 = house_14.sum(axis=1)
house_14

df7 = house_14.to_frame(name="House Count")
df7

df7['year'] = 2014
df7
# Out:
#     House Count  year
# 21     106420.0  2014

# %%
house_15 = CO_df[['2015-01','2015-02','2015-03','2015-04','2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12']]
house_15

house_15 = house_15.sum(axis=1)
house_15

df8 = house_15.to_frame(name="House Count")
df8

df8['year'] = 2015
df8
# Out:
#     House Count  year
# 21     116584.0  2015

# %%
house_16 = CO_df[['2016-01','2016-02','2016-03','2016-04','2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12']]
house_16

house_16 = house_16.sum(axis=1)
house_16

df9 = house_16.to_frame(name="House Count")
df9

df9['year'] = 2016
df9
# Out:
#     House Count  year
# 21     117951.0  2016

# %%
house_17 = CO_df[['2017-01','2017-02','2017-03','2017-04','2017-05', '2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12']]
house_17

house_17 = house_17.sum(axis=1)
house_17

df10 = house_17.to_frame(name="House Count")
df10

df10['year'] = 2017
df10
# Out:
#     House Count  year
# 21     121204.0  2017

# %%
house_18 = CO_df[['2018-01','2018-02','2018-03','2018-04','2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12']]
house_18

house_18 = house_18.sum(axis=1)
house_18

df11 = house_18.to_frame(name="House Count")
df11

df11['year'] = 2018
df11
# Out:
#     House Count  year
# 21       115930  2018

# %%
houses_sold_year = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11], ignore_index=True, axis=0)
houses_sold_year

co_df = pd.DataFrame(houses_sold_year)
co_df
# Out:
#     House Count  year
# 0       75043.0  2008
# 1       75006.0  2009
# 2       72002.0  2010
# 3       73092.0  2011
# 4       87356.0  2012
# 5      102795.0  2013
# 6      106420.0  2014
# 7      116584.0  2015
# 8      117951.0  2016
# 9      121204.0  2017
# 10     115930.0  2018

# %%
houses_sold_year.plot(kind='bar' , x = 'year')
houses_sold_year
plt.title('Houses Purchasedin CO 2008-2018')
plt.ylabel("# of houses")
plt.xlabel('Year')
plt.show()
